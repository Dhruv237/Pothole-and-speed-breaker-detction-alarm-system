# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %%
# !yolo mode=train task=detect data=/content/pothole_speedbreaker_data.yaml  model=yolov8m.pt epochs=50 imgsz=640
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 261MB/s]
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
